# %%
import pandas as pd
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
min_df = pd.read_csv("today_min_prices.csv", index_col=0)
max_df = pd.read_csv("today_max_prices.csv", index_col=0)
avg_df = pd.read_csv("today_avg_prices.csv", index_col=0)
lang_df = pd.read_csv("vegetableLanguage.csv", index_col=0)

# %%
min_df_transposed = min_df.T
max_df_transposed = max_df.T
avg_df_transposed = avg_df.T

# %%
combined_df = pd.concat([min_df_transposed, max_df_transposed, avg_df_transposed], axis=1)
combined_df.columns = ['Min Price', 'Max Price', 'Avg Price']

# %%
lang_df
# Out:
#     Unnamed: 0                    English                        Nepali
# 0            0    Tomato Big(Indian) (KG)   गोलभेडा ठूलो(भारतीय) (केजी)
# 1            1   Tomato Small(Local) (KG)   गोलभेडा सानो(लोकल) (के.जी.)
# 2            2  Tomato Small(Tunnel) (KG)    गोलभेडा सानो(टनेल) (के जी)
# 3            3  Tomato Small(Indian) (KG)  गोलभेडा सानो(भारतीय) (के जी)
# 4            4            Potato Red (KG)             आलु रातो (के.जी.)
# ..         ...                        ...                           ...
# 93          93      Fish Fresh(Rahu) (KG)        ताजा माछा(रहु) (के जी)
# 94          94   Fish Fresh(Bachuwa) (KG)      ताजा माछा(बचुवा) (के जी)
# 95          95    Fish Fresh(Chhadi) (KG)        ताजा माछा(छडी) (के जी)
# 96          96   Fish Fresh(Mungari) (KG)     ताजा माछा(मुंगरी) (के जी)
# 97          97           Tree Tomato (Kg)              रुख टमाटर (केजी)
#
# [98 rows x 3 columns]

# %%
min_df
# Out:
#             Tomato Big(Indian) (KG)  Tomato Small(Local) (KG)  \
# 2023-10-15                       35                        30
#
#             Tomato Small(Tunnel) (KG)  Tomato Small(Indian) (KG)  \
# 2023-10-15                         32                         30
#
#             Potato Red (KG)  Potato Red(Indian) (KG)  Potato Red(Mude) (KG)  \
# 2023-10-15               60                       34                     42
#
#             Potato White (KG)  Onion Dry (Indian) (KG)  Carrot(Local) (KG)  \
# 2023-10-15                 42                       74                 110
#
#             ...  Garlic Green (KG)  Coriander Green (KG)  \
# 2023-10-15  ...                280                   120
#
#             Garlic Dry Chinese (KG)  Garlic Dry Nepali (KG)  Clive Dry (KG)  \
# 2023-10-15                      220                     260             180
#
#             Fish Fresh(Rahu) (KG)  Fish Fresh(Bachuwa) (KG)  \
# ...

# %%
min_df_transposed
# Out:
#                            2023-10-15
# Tomato Big(Indian) (KG)            35
# Tomato Small(Local) (KG)           30
# Tomato Small(Tunnel) (KG)          32
# Tomato Small(Indian) (KG)          30
# Potato Red (KG)                    60
# ...                               ...
# Fish Fresh(Rahu) (KG)             370
# Fish Fresh(Bachuwa) (KG)          270
# Fish Fresh(Chhadi) (KG)           240
# Fish Fresh(Mungari) (KG)          250
# Tree Tomato (Kg)                  120
#
# [98 rows x 1 columns]
