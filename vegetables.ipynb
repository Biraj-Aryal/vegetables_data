# %%
import pandas as pd
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
lang_df = pd.read_csv("vegetableLanguage.csv", index_col=0)

min_df_transposed = df_min.T
max_df_transposed = df_max.T
avg_df_transposed = df_avg.T

lang_df.set_index('English', inplace=True)
lang_df_reordered = lang_df.loc[min_df_transposed.index]
combined_df = pd.concat([lang_df_reordered, min_df_transposed, max_df_transposed, avg_df_transposed], axis=1)
combined_df.columns = ['Nepali', 'Min Price', 'Max Price', 'Avg Price']
combined_df.to_csv("today_prices.csv")

# %%
combined_df
# Out:
#                                                  Nepali  Min Price  Max Price  \
# Tomato Big(Indian) (KG)     गोलभेडा ठूलो(भारतीय) (केजी)         35         40
# Tomato Small(Local) (KG)    गोलभेडा सानो(लोकल) (के.जी.)         30         35
# Tomato Small(Tunnel) (KG)    गोलभेडा सानो(टनेल) (के जी)         32         42
# Tomato Small(Indian) (KG)  गोलभेडा सानो(भारतीय) (के जी)         30         35
# Potato Red (KG)                       आलु रातो (के.जी.)         60         65
# ...                                                 ...        ...        ...
# Fish Fresh(Rahu) (KG)            ताजा माछा(रहु) (के जी)        370        380
# Fish Fresh(Bachuwa) (KG)       ताजा माछा(बचुवा) (के जी)        270        280
# Fish Fresh(Chhadi) (KG)          ताजा माछा(छडी) (के जी)        240        260
# Fish Fresh(Mungari) (KG)      ताजा माछा(मुंगरी) (के जी)        250        270
# Tree Tomato (Kg)                       रुख टमाटर (केजी)        120        150
#
#                            Avg Price
# Tomato Big(Indian) (KG)        37.67
# Tomato Small(Local) (KG)       32.67
# Tomato Small(Tunnel) (KG)      36.00
# Tomato Small(Indian) (KG)      32.67
# Potato Red (KG)                62.33
# ...                              ...
# Fish Fresh(Rahu) (KG)         375.00
# Fish Fresh(Bachuwa) (KG)      275.00
# Fish Fresh(Chhadi) (KG)       250.00
# Fish Fresh(Mungari) (KG)      260.00
# Tree Tomato (Kg)              133.33
#
# [98 rows x 4 columns]
